# %% [markdown]
# ## Exception handling
# - NameError
# - TypeError
# - ZeroDivisiovError
# - etc

# %%
a=c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-eb70dc206e9a> in <cell line: 0>()
# ----> 1 a=c
#
# NameError: name 'c' is not defined

# %%
try:
  a=c
except Exception as ex:
  print(ex)
# Out:
# name 'c' is not defined

# %%
try:
  ## code block where exception can occur
  a=c
except:
  print('some problem may have occured')
# Out:
# some problem may have occured

# %%
try:
  a=c
except NameError as ex1:
  print('the user have not defined the variable')
except Exception as ex:
  print(ex)
# Out:
# the user have not defined the variable

# %%
a=1
b='str'
c=a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f1182867e8ec> in <cell line: 0>()
#       1 a=1
#       2 b='str'
# ----> 3 c=a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
  a=1
  b='str'
  c=a+b
except NameError as ex1:
  print('the user have not defined the variable')
except Exception as ex:
  print(ex)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
  a=1
  b='str'
  c=a+b
except NameError:
  print('the user have not defined the variable')
except TypeError:
  print('try to make the datatype similar')
except Exception as ex:
  print(ex)
# Out:
# try to make the datatype similar

# %%
try:
  a=int(input("enter the num1 "))
  b=int(input("enter the num2 "))
  c=a/b
  d=a*b
  e=a+b
  print(c)
  print(d)
  print(e)
except NameError:
  print('the user have not defined the variable')
except TypeError:
  print('try to make the datatype similar')
except Exception as ex:
  print(ex)
# Out:
# enter the num1 12
# enter the num2 2
# 6.0
# 24
# 14

# %%
try:
  a=int(input("enter the num1 "))
  b=int(input("enter the num2 "))
  c=a/b
  d=a*b
  e=a+b
  print(c)
  print(d)
  print(e)
except NameError:
  print('the user have not defined the variable')
except TypeError:
  print('try to make the datatype similar')
except Exception as ex:
  print(ex)
# Out:
# enter the num1 12
# enter the num2 0
# division by zero

# %%
12/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-898e9759c56e> in <cell line: 0>()
# ----> 1 12/0
#
# ZeroDivisionError: division by zero

# %%
try:
  a=int(input("enter the num1 "))
  b=int(input("enter the num2 "))
  c=a/b
  d=a*b
  e=a+b
  print(c)
  print(d)
  print(e)
except NameError:
  print('the user have not defined the variable')
except TypeError:
  print('try to make the datatype similar')
except ZeroDivisionError:
  print("please provide number greater than 0")
except Exception as ex:
  print(ex)
# Out:
# enter the num1 12
# enter the num2 0
# please provide number greater than 0

# %%
try: # try else
  a=int(input("enter the num1 "))
  b=int(input("enter the num2 "))
  c=a/b
  d=a*b
  e=a+b

except NameError:
  print('the user have not defined the variable')
except TypeError:
  print('try to make the datatype similar')
except ZeroDivisionError:
  print("please provide number greater than 0")
except Exception as ex:
  print(ex)
else:
  print(c)
  print(d)
  print(e)
finally:
  print('the excution is done')
# Out:
# enter the num1 12
# enter the num2 3
# 4.0
# 36
# 15
# the excution is done

# %%
try: # try else
  a=int(input("enter the num1 "))
  b=int(input("enter the num2 "))
  c=a/b
  d=a*b
  e=a+b

except NameError:
  print('the user have not defined the variable')
except TypeError:
  print('try to make the datatype similar')
except ZeroDivisionError:
  print("please provide number greater than 0")
except Exception as ex:
  print(ex)
else:
  print(c)
  print(d)
  print(e)
finally:
  print('the excution is done')
# Out:
# enter the num1 14
# enter the num2 0
# please provide number greater than 0
# the excution is done

# %%
class Error(Exception):
  pass

class dobException(Error):
  pass

# %%
year=int(input('enter the year of birth '))
age=2024-year
try:
  if age<=30 & age>20:
    print('the age is valid ,you can apply for the exam')
  else:
    raise dobException
except dobException:
  print('the age is not valid,u canot apply for the xam')
# Out:
# enter the year of birth 12
# the age is not valid,u canot apply for the xam

# %%
year=int(input('enter the year of birth '))
age=2024-year
try:
  if age<=30 & age>20:
    print('the age is valid ,you can apply for the exam')
  else:
    raise dobException
except dobException:
  print('the age is not valid,u canot apply for the xam')
# Out:
# enter the year of birth 1998
# the age is valid ,you can apply for the exam

# %% [markdown]
# # File Handling
#
# ## Directory in Python

# %%
#Current Working Directory (CWD)
import os

cwd = os.getcwd()
print(f"Current Working Directory: {cwd}")
# Out:
# Current Working Directory: C:\Users\USER\0) my_full_python

# %%
# #Changing the CWD
# import os

# print("Before changing:", os.getcwd())
# os.chdir("/Users/USER/0) my_full_python")#first i changed to dataset folder and again I did
# print("After changing:", os.getcwd())

# %%
# Listing Files and Sub-directories
import os
print("Files and directories inside the CWD:", os.listdir())
# Out:
# Files and directories inside the CWD: ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb']

# %%
# Creating a New Directory
import os
print("Before creating:", os.listdir())
os.mkdir("practise1") 
print("After creating:", os.listdir())
# Out:
# Before creating: ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb']
# After creating: ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb', 'practise1']

# %%
#Renaming a Python Directory

import os

print("Before renaming:", os.listdir())
print(os.rename("practise1", 'practise'))
print("After renaming:", os.listdir())
# Out:
# Before renaming: ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb', 'practise1']
# None
# After renaming: ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb', 'practise']

# %%
# Verifying the Existence of a Directory

import os

print(os.listdir())
print(os.path.exists('practise'))
print(os.path.exists('practise1'))
# Out:
# ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb', 'practise']
# True
# False

# %%
# Removing a Directory in Python

import os
print("Before Removing:", os.listdir())
print(os.rmdir("practise"))
print("After Removing:", os.listdir())
# Out:
# Before Removing: ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb', 'practise']
# None
# After Removing: ['.ipynb_checkpoints', 'my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb']

# %%
# Last Modification Time of a Python Directory

import os
import datetime

m_time = os.path.getmtime('/Users/USER/0) my_full_python')
print(m_time)
time = datetime.datetime.fromtimestamp(m_time).strftime("%d-%m-%Y %H:%M:%S")
print(f"The Directory is last modified on {time}")
# Out:
# 1744551355.7858224
# The Directory is last modified on 13-04-2025 19:05:55

# %%
# Last Access Time of Python Directory
import os
import datetime

a_time = os.path.getatime('/Users/USER/0) my_full_python')
print(a_time)
time = datetime.datetime.fromtimestamp(a_time).strftime("%d-%m-%Y %H:%M:%S")
print(f"The Directory is last accessed on {time}")
# Out:
# 1744551356.6170163
# The Directory is last accessed on 13-04-2025 19:05:56

# %%
# Creating Platform-independent Directories in Python

# split()

import os.path

dir = "/Users/USER/0) my_full_python/PythonG"
print(os.path.split(dir))
# Out:
# ('/Users/USER/0) my_full_python', 'PythonG')

# %%
# join(path, *paths)

import os.path

dir = ('/Users/apple/PythonProjects', 'PythonGeeks')
print(os.path.join(dir[0], dir[1]))
# Out:
# /Users/apple/PythonProjects\PythonGeeks

# %%
# Traversing Directories Recursively using Python

import os

for i, j, k in os.walk(os.getcwd()):
   print("path:", i)
   print("List of directories:", j)
   print("List of files:", k)
# Out:
# path: C:\Users\USER\0) my_full_python
# List of directories: ['.ipynb_checkpoints']
# List of files: ['my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb']
# path: C:\Users\USER\0) my_full_python\.ipynb_checkpoints
# List of directories: []
# List of files: ['my_python_3_functions-checkpoint.ipynb', 'my_python_5_Exceptional_&_filehandling-checkpoint.ipynb']

# %%
# Getting the Size of a Directory in Python
import os
print(os.path.getsize('/Users/USER/0) my_full_python'))
# Out:
# 4096

# %%
# Comparing Directories

## cmpfiles(dir1, dir2, common)

import filecmp as fc

dir1 = "/Users/USER/0) my_full_python/1)Datasets"

common = ["geeks.py"]
print(fc.cmpfiles(dir1, dir1, common))
# Out:
# ([], [], ['geeks.py'])

# %%
# dircmp
import filecmp as fc

dir1 = "/Users/USER/0) my_full_python"
dir2 = "/Users/USER/1)Datasets"

cmp = fc.dircmp(dir1, dir2)
print(cmp)

# %%
# report()
print(cmp.report())
# Out:
# diff /Users/USER/0) my_full_python /Users/USER/1)Datasets
# Only in /Users/USER/0) my_full_python : ['my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb']
# Only in /Users/USER/1)Datasets : ['employee_dump.sql', 'music.csv', 'test1.csv', 'titanic_train.csv', 'workspace.code-workspace']
# Common subdirectories : ['.ipynb_checkpoints']
# None

# %%
# report_partial_closure()
print(cmp.report_partial_closure())
# Out:
# diff /Users/USER/0) my_full_python /Users/USER/1)Datasets
# Only in /Users/USER/0) my_full_python : ['my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb']
# Only in /Users/USER/1)Datasets : ['employee_dump.sql', 'music.csv', 'test1.csv', 'titanic_train.csv', 'workspace.code-workspace']
# Common subdirectories : ['.ipynb_checkpoints']
#
# diff /Users/USER/0) my_full_python\.ipynb_checkpoints /Users/USER/1)Datasets\.ipynb_checkpoints
# Only in /Users/USER/0) my_full_python\.ipynb_checkpoints : ['my_python_3_functions-checkpoint.ipynb', 'my_python_5_Exceptional_&_filehandling-checkpoint.ipynb']
# Only in /Users/USER/1)Datasets\.ipynb_checkpoints : ['employee_dump-checkpoint.sql', 'music-checkpoint.csv', 'test1-checkpoint.csv', 'titanic_train-checkpoint.csv', 'workspace-checkpoint.code-workspace']
# None

# %%
# report_full_clousre()
print(cmp.report_full_closure())
# Out:
# diff /Users/USER/0) my_full_python /Users/USER/1)Datasets
# Only in /Users/USER/0) my_full_python : ['my_python_3_functions.ipynb', 'my_python_5_Exceptional_&_filehandling.ipynb']
# Only in /Users/USER/1)Datasets : ['employee_dump.sql', 'music.csv', 'test1.csv', 'titanic_train.csv', 'workspace.code-workspace']
# Common subdirectories : ['.ipynb_checkpoints']
#
# diff /Users/USER/0) my_full_python\.ipynb_checkpoints /Users/USER/1)Datasets\.ipynb_checkpoints
# Only in /Users/USER/0) my_full_python\.ipynb_checkpoints : ['my_python_3_functions-checkpoint.ipynb', 'my_python_5_Exceptional_&_filehandling-checkpoint.ipynb']
# Only in /Users/USER/1)Datasets\.ipynb_checkpoints : ['employee_dump-checkpoint.sql', 'music-checkpoint.csv', 'test1-checkpoint.csv', 'titanic_train-checkpoint.csv', 'workspace-checkpoint.code-workspace']
# None

# %% [markdown]
# # Copy Files
# there are a total of nine unique functions in Python that we can use to copy a file.
#
# - Copyfile() vs copy() vs copy2() vs copyfileobj() in Python

# %% [markdown]
# |Functions       | Copies Content | Copies Permissions |  Copies Metadata |  Can pass a directory as dst |    Can pass a file descriptors    |
# |-----------|---------|------------|---------|----------------|----------------|
# |copyfile   |	Yes	  |    No	   |   No	 |      No        |      No        |
# |copy	    |    Yes  |    Yes     |   No    |      Yes       |   	 No        |
# |copy2	    |    Yes  |    Yes     |   Yes   |      Yes	      |      No        |
# |copyfileobj|	Yes   |    No	   |   No    |      No	      |      yes       |

# %%
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# %%
# 1. Copyfile(src, dst)

import shutil
import os

path = "E:\my_python"

src = path + '\python1.py'
dst = path + '\lemonade3'

print(f"Before copying\n{os.listdir(path)}")

print(shutil.copyfile(src, dst))

print(f"After copying\n{os.listdir(path)}")
# Out:
# Before copying
# ['.venv', 'lemonade2', 'lemonade3', 'my_python_3_functions.ipynb', 'python1.py', 'python2.ipynb']
# E:\my_python\lemonade3
# After copying
# ['.venv', 'lemonade2', 'lemonade3', 'my_python_3_functions.ipynb', 'python1.py', 'python2.ipynb']

# %%
# 1. Copyfile(src, dst)

import shutil
import os

path = "E:\my_python"

src = path + '\python1.py'
dst = path + '\lemonade4'

print(f"Before copying\n{os.listdir(path)}")

print(shutil.copy(src, dst)) # like this we can copy2(), copyfileobj()

print(f"After copying\n{os.listdir(path)}")
# Out:
# Before copying
# ['.venv', 'lemonade2', 'lemonade3', 'lemonade4', 'my_python_3_functions.ipynb', 'python1.py', 'python2.ipynb']
# E:\my_python\lemonade4
# After copying
# ['.venv', 'lemonade2', 'lemonade3', 'lemonade4', 'my_python_3_functions.ipynb', 'python1.py', 'python2.ipynb']

# %%
#Changing the CWD
import os

print("Before changing:", os.getcwd())
os.chdir("E:\my_python")#first i changed to dataset folder and again I did
print("After changing:", os.getcwd())
# Out:
# Before changing: E:\my_python
# After changing: E:\my_python

# %%
os.listdir()
# Out:
# ['my_python_3_functions.ipynb', 'python1.py', 'python2.ipynb']

# %% [markdown]
# # have to learn about zipping files
